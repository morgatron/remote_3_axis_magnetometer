# %%
from pylab import *
import numpy as np

# %%
dat=np.load('acquisition6.npy')

# %%
dat
# Out:
# array([( 979.968243, 19210, -41987, 1634, 12582912),
#        ( 979.969246, 19191, -42025, 1612, 12582912),
#        ( 979.970246, 19202, -41958, 1620, 12582912), ...,
#        (1000.276031, 19241, -42050, 1675, 12582912),
#        (1000.277032, 19238, -42016, 1682, 12582912),
#        (1000.278035, 19248, -41943, 1680, 12582912)],
#       shape=(20251,), dtype=[('time_s', '<f8'), ('x', '<i4'), ('y', '<i4'), ('z', '<i4'), ('status', '<u4')])

# %%
STATUS_OK=dat['status'][5]

# %%
plot(dat['x'][np.where(dat['status'] == STATUS_OK)[0]] )
